# %%
import panel as pn
pn.extension()

import pandas as pd
import hvplot.pandas
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='f4fac0f6-1542-47be-91f2-eab981240f1a'>
#   <div id="ab2073f2-a34f-4047-b409-9f8eb06b87cb" data-root-id="f4fac0f6-1542-47be-91f2-eab981240f1a" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# Reading the dataset

# %%
df = pd.read_csv('data/steinmetz_summer2017.csv')
df.head()
# Out:
#    trial  active_trials  contrast_left  contrast_right  stim_onset  \
# 0      1           True              0              50         0.5
# 1      2           True             50               0         0.5
# 2      3           True              0               0         0.5
# 3      4           True              0               0         0.5
# 4      5           True              0               0         0.5
#
#    gocue_time  response_type  response_time  feedback_time  feedback_type  \
# 0    0.788413           -1.0       1.141331       1.178420            1.0
# 1    0.849215            1.0       0.932758       0.970017            1.0
# 2    0.827614           -1.0       1.299385       1.299385           -1.0
# 3    1.103619            1.0       1.232597       1.232597           -1.0
# 4    1.140420            1.0       1.682664       1.682664           -1.0
#
#    reaction_time  reaction_type  mouse session_date session_id
# ...

# %%
df[['response_time']].hvplot.hist()
# Out:
# :Histogram   [response_time]   (Count)

# %%
df[['response_time']].hvplot.box()
# Out:
# :BoxWhisker   (response_time)

# %%
df[['feedback_time']].hvplot.hist()
# Out:
# :Histogram   [feedback_time]   (Count)

# %%
plot_1 = df[['response_time']].hvplot.hist()
plot_2 = df[['feedback_time']].hvplot.hist()

# %%
dashboard = pn.Column(plot_1, plot_2)
dashboard.servable()
# Out:
# Column
#     [0] HoloViews(Histogram, height=300, sizing_mode='fixed', width=700)
#     [1] HoloViews(Histogram, height=300, sizing_mode='fixed', width=700)
