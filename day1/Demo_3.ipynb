# %%
import panel as pn
pn.extension()

import pandas as pd
import hvplot.pandas
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='fc6c5b74-0635-4f62-83b1-bb4fc98dd63d'>
#   <div id="f429d2bf-931b-4443-a5ab-ce9eca224e52" data-root-id="fc6c5b74-0635-4f62-83b1-bb4fc98dd63d" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
df = pd.read_csv('data/steinmetz_winter2017.csv')
df.head()
# Out:
#    trial  active_trials  contrast_left  contrast_right  stim_onset  \
# 0      1           True            100               0         0.5
# 1      2           True              0             100         0.5
# 2      3           True              0             100         0.5
# 3      4           True              0              25         0.5
# 4      5           True            100              25         0.5
#
#    gocue_time  response_type  response_time  feedback_time  feedback_type  \
# 0    0.508117            1.0       0.903312       0.946524            1.0
# 1    0.678304            1.0       0.859908       0.859908           -1.0
# 2    0.508295           -1.0       0.646241       0.683098            1.0
# 3    0.437219           -1.0       0.985264       1.022429            1.0
# 4    0.672789            1.0       1.137715       1.175197            1.0
#
#    reaction_time  reaction_type    mouse session_date session_id
# ...

# %%
df[['response_time']].hvplot.explorer()
# Out:
# hvDataFrameExplorer(advanced=Advanced(explorer=..., name='Advanced02070', opts=None), axes=Axes(explorer=..., height=None, legend='bottom_right', logx=False, logy=False, name='Axes02064', responsive=True, shared_axes=True, width=None, xlim=None, ylim=None), by=[], code="df.hvplot(\n    kind='scatter',\n    x='index',\n    legend='bottom_right',\n    widget_location='bottom',\n)", colormapping=Colormapping(clim=None, cmap='kbc_r', cnorm='linear', color=None, colorbar=None, explorer=..., name='Colormapping02065', rescale_discrete_levels=True, symmetric=False), geographic=Geographic(crs=None, crs_kwargs={}, explorer=..., feature_scale='110m', features=None, geo=False, global_extent=None, name='Geographic02067', project=False, projection=None, projection_kwargs={}, tiles=None), groupby=[], kind='scatter', labels=Labels(clabel='', explorer=..., fontscale=1, name='Labels02066', rot=0, title='', xlabel='', ylabel=''), name='hvDataFrameExplorer02042', operations=Operations(aggregator=None, d
# ...

# %%
df[['response_time', 'feedback_time', 'mouse']].hvplot.explorer()
# Out:
# hvDataFrameExplorer(advanced=Advanced(explorer=..., name='Advanced03105', opts=None), axes=Axes(explorer=..., height=None, legend='bottom_right', logx=False, logy=False, name='Axes03099', responsive=True, shared_axes=True, width=None, xlim=None, ylim=None), by=[], code="df.hvplot(\n    kind='scatter',\n    x='index',\n    legend='bottom_right',\n    widget_location='bottom',\n)", colormapping=Colormapping(clim=None, cmap='kbc_r', cnorm='linear', color=None, colorbar=None, explorer=..., name='Colormapping03100', rescale_discrete_levels=True, symmetric=False), geographic=Geographic(crs=None, crs_kwargs={}, explorer=..., feature_scale='110m', features=None, geo=False, global_extent=None, name='Geographic03102', project=False, projection=None, projection_kwargs={}, tiles=None), groupby=[], kind='scatter', labels=Labels(clabel='', explorer=..., fontscale=1, name='Labels03101', rot=0, title='', xlabel='', ylabel=''), name='hvDataFrameExplorer03077', operations=Operations(aggregator=None, d
# ...

# %%
plot_1 = df['response_time'].hvplot.hist()
plot_2 = df['feedback_time'].hvplot.hist()
dashboard = pn.Column(plot_1, plot_2)

# %%
dashboard.servable()
# Out:
# Column
#     [0] HoloViews(Histogram, height=300, sizing_mode='fixed', width=700)
#     [1] HoloViews(Histogram, height=300, sizing_mode='fixed', width=700)
